# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from stft import *

# %%
argument = stft_argument()
stft = STFT(argument)
sound = SoundData()

# %%
tmax = stft.t_int*2 #sec
M = np.empty((stft.N_T+1, stft.N_T+1), dtype=complex)
for i,nu in enumerate(stft.frequencies):
        data = A*np.cos(2*np.pi*nu*trange)
        stft(data)
        M[i] = stft.data[0]
Minv = np.linalg.pinv(M)

# %%
plt.plot(Minv@M[245], 'x-')
plt.xlabel('log(frequency) [Hz]')
plt.ylabel('power')
plt.grid(True)
plt.xscale('log')
plt.show()
# Out:
# /home/antal/Documents/Wavelet-transform/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/antal/Documents/Wavelet-transform/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
Minv.shape
# Out:
# (2206, 2206)

# %%
tmax = 1 #sec
nu = 201.8 #Hz
A = 1
trange = stft.range(0,tmax)
data = A*np.sin(2*np.pi*nu*trange)
stft(data)

# %%
tmax = 1 #sec
nu = 201.8 #Hz
trange = stft.range(0,tmax)
stft(np.cos(2*np.pi*nu*trange))
u = Minv @ stft.data[0]
plt.plot(np.log(stft.frequencies+1), data_view(stft.data[0], 'spectrum'), 'x-')
plt.plot(np.log(stft.frequencies+1), data_view(u, 'spectrum'), 'x-')
ax.set_xlabel('log(frequency) [Hz]')
ax.set_ylabel('power')
ax.grid(True)
plt.show()
