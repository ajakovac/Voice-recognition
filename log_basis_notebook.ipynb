# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
import importlib
import log_basis
from models import StftArgument

# %%
argument = StftArgument()

# %%
argument.stft_default_window(0.1)
# Out:
# 0.9999360040957378

# %%
lb = log_basis.LogBasis(argument)

# %%
lb.frequencies[-1]
# Out:
# np.float64(12435.608846766152)

# %%
plt.plot(lb.nrange*lb.dt, lb.basis[:,0].real)

# %%
lb.basis.shape
# Out:
# (4410, 192)

# %%
lb.PCA_matrix.shape
# Out:
# (192, 4410)

# %%
tmax = 1 #sec
nu = 201.8 #Hz
A = 1
trange = np.arange(0, tmax, lb.dt)
data = A*np.sin(2*np.pi*nu*trange)
plt.plot(trange, data)

# %%
spectrogram, times, frequencies = lb.transform(data)

# %%
plt.plot(spectrogram[:,1].imag)
